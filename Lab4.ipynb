# %%
import os
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import dash
from dash import dcc, html, Input, Output
import tkinter as tk
from tkinter import filedialog

# ====================
# Data Loading using Tkinter
# ====================
root = tk.Tk()
root.withdraw()  # Hide the root Tk window
#Caj Rollny; the original code - "filedialog.askopenfilename" - didn't work. Tried adding this line of code after googling, worked:
root.call('wm', 'attributes', '.', '-topmost', True)

print("Imports done, Tk initiated")


# Define file keys for CSV files.
# Caj Rollny: plot only between Mora and Borlänge!
# Tried some datasets "manually" with this code and found the corresponding datasets:
# Mora -> Leksand: 2024-12-10 10-00-00 (1)
# Leksand -> Borlänge: 2024-12-10 12-00-00 (1)
# 1. merge theese datasets into new datasets and save as new files:
# https://stackoverflow.com/questions/48051100/python-pandas-merge-multiple-csv-files

#Caj Rollny: NB! The file generation below took about 15 minutes in total. Uncomment the code below if the files need to be re-generated!
'''
#GPS Latitude:
df_GPS_lat1 = pd.read_csv("C:\Temp\D7015B\Data2\\2024-12-10 10-00-00 (1)\\GPS.latitude.csv", header=None)
df_GPS_lat2 = pd.read_csv("C:\Temp\D7015B\Data2\\2024-12-10 12-00-00 (1)\\GPS.latitude.csv", header=None)
df_GPS_lat_combined = pd.concat([df_GPS_lat1,df_GPS_lat2])
#save combined dataset as new file:
df_GPS_lat_combined.to_csv("C:\Temp\D7015B\GPS.latitude.csv",index=None)
#free memory:
del df_GPS_lat1
del df_GPS_lat2
del df_GPS_lat_combined

#GPS longitude:
df_GPS_lon1 = pd.read_csv("C:\Temp\D7015B\Data2\\2024-12-10 10-00-00 (1)\\GPS.longitude.csv", header=None)
df_GPS_lon2 = pd.read_csv("C:\Temp\D7015B\Data2\\2024-12-10 12-00-00 (1)\\GPS.longitude.csv", header=None)
df_GPS_lon_combined = pd.concat([df_GPS_lon1,df_GPS_lon2])
#save combined dataset as new file:
df_GPS_lon_combined.to_csv("C:\Temp\D7015B\GPS.longitude.csv",index=None)
#free memory:
del df_GPS_lon1
del df_GPS_lon2
del df_GPS_lon_combined

#GPS Speed:
df_GPS_speed1 = pd.read_csv("C:\Temp\D7015B\Data2\\2024-12-10 10-00-00 (1)\\GPS.speed.csv", header=None)
df_GPS_speed2 = pd.read_csv("C:\Temp\D7015B\Data2\\2024-12-10 12-00-00 (1)\\GPS.speed.csv", header=None)
df_GPS_speed_combined = pd.concat([df_GPS_speed1,df_GPS_speed2])
#save combined dataset as new file:
df_GPS_speed_combined.to_csv("C:\Temp\D7015B\GPS.speed.csv",index=None)
#free memory:
del df_GPS_speed1
del df_GPS_speed2
del df_GPS_speed_combined

#Vibration 1:
df_VIB1_1 = pd.read_csv("C:\Temp\D7015B\Data2\\2024-12-10 10-00-00 (1)\\CH1_ACCEL1Z1.csv", header=None)
df_VIB1_2 = pd.read_csv("C:\Temp\D7015B\Data2\\2024-12-10 12-00-00 (1)\\CH1_ACCEL1Z1.csv", header=None)
df_VIB1_combined = pd.concat([df_VIB1_1,df_VIB1_2])
#save combined dataset as new file:
df_VIB1_combined.to_csv("C:\Temp\D7015B\CH1_ACCEL1Z1.csv",index=None)

#free memory:
del df_VIB1_1
del df_VIB1_2
del df_VIB1_combined

#Vibration 2:
df_VIB2_1 = pd.read_csv("C:\Temp\D7015B\Data2\\2024-12-10 10-00-00 (1)\\CH2_ACCEL1Z2.csv", header=None)
df_VIB2_2 = pd.read_csv("C:\Temp\D7015B\Data2\\2024-12-10 12-00-00 (1)\\CH2_ACCEL1Z2.csv", header=None)

df_VIB2_combined = pd.concat([df_VIB2_1,df_VIB2_2])
#save combined dataset as new file:
df_VIB2_combined.to_csv("C:\Temp\D7015B\CH2_ACCEL1Z2.csv",index=None)

#free memory:
del df_VIB2_1
del df_VIB2_2
del df_VIB2_combined

'''

#TODO: clean the data; a lot of GPS-data must be removed, look at GPS-speed and remove bad/irrelevant data?
#define the new files:
files = {
    "latitude": "C:\Temp\D7015B\GPS.latitude.csv",
    "longitude": "C:\Temp\D7015B\GPS.longitude.csv",
    "vibration1": "C:\Temp\D7015B\CH1_ACCEL1Z1.csv",
    "vibration2": "C:\Temp\D7015B\CH2_ACCEL1Z2.csv",
    "speed": "C:\Temp\D7015B\GPS.speed.csv"
}

'''
def load_file(key):
    print("In function load_file, askopen filename")
    file_path = filedialog.askopenfilename(filetypes=[("CSV Files", "*.csv")])
    if file_path:
        files[key] = file_path
        print(f"{key.capitalize()} file loaded: {file_path}")

#Caj Rollny: hard-coded the files above. 
print("Select Latitude File")
load_file("latitude")
print("Select Longitude File")
load_file("longitude")
print("Select Vibration 1 File")
load_file("vibration1")
print("Select Vibration 2 File")
load_file("vibration2")
print("Select Speed File")
load_file("speed")
'''

# Load each CSV into a DataFrame and add a 'timestamp' using the row index.
dataframes = {}
for key, file_path in files.items():
    if file_path:
        df = pd.read_csv(file_path, header=None, names=[key])
        df['timestamp'] = df.index
        dataframes[key] = df
    else:
        print(f"{key.capitalize()} file not selected.")

print("loading data in dataframes finished.")



# ====================
# Create GPS DataFrame by merging latitude and longitude.
# ====================
if "latitude" in dataframes and "longitude" in dataframes:
    df_gps = pd.merge(dataframes["latitude"], dataframes["longitude"], on="timestamp")
    # Rename columns for consistency
    df_gps = df_gps.rename(columns={"latitude": "Latitude", "longitude": "Longitude"})
    # Add an index column for use in the interactive plot
    df_gps["PointIndex"] = df_gps.index
else:
    print("Latitude or Longitude data is missing.")
    df_gps = pd.DataFrame(columns=["Latitude", "Longitude", "PointIndex"])
#debug: save ther resulting gps datafram to file:
#df_gps.to_csv("C:\Temp\D7015B\GPS_resulting.csv")

print("creating GPS merged dataframes finished.")

# ====================
# Merge the two vibration signals on 'timestamp'
# ====================
if "vibration1" in dataframes and "vibration2" in dataframes:
    df_vibration_merged = pd.merge(
        dataframes["vibration1"],
        dataframes["vibration2"],
        on="timestamp"
        # When the column names differ (here: vibration1 vs vibration2), suffixes are not needed.
    )
    # You may rename columns if desired; here they remain "vibration1" and "vibration2"
else:
    print("Vibration data files are missing.")
    df_vibration_merged = pd.DataFrame()

print("merging vibration dataframes on timestamp finished.")

# ====================
# Data Preprocessing and Segmentation for Vibration Data
# ====================
dt_vibration = 0.002  # seconds per sample (e.g. 500 Hz sampling rate)
segment_duration_seconds = 10
segment_length = int(segment_duration_seconds / dt_vibration)
print("segment_length: ", segment_length)
if not df_vibration_merged.empty:
    num_segments = len(df_vibration_merged) // segment_length
    print("num_segments: ", num_segments)
    segments = []
    for i in range(num_segments):
        seg = df_vibration_merged.iloc[i * segment_length: (i + 1) * segment_length][["vibration1", "vibration2"]].values
        segments.append(seg)
    segments = np.array(segments)
    #print("Segmented vibration data shape:", segments.shape)

else:
    segments = np.array([])
    print("No vibration data available for segmentation.")

print("Data preprocessing and segmentation for vibration data finished.")
#print("Segments: ", segments)
# ====================
# Build the Interactive Dash App
# ====================

# Create the interactive GPS map using Plotly Express.
if not df_gps.empty:
    # Use custom_data to store the point index so that it will be available in callbacks.
    map_fig = px.scatter_mapbox(
        df_gps,
        lat="Latitude",
        lon="Longitude",
        custom_data=["PointIndex"],
        zoom=10,
        title="GPS Points with Vibration Data"
    )
    map_fig.update_layout(mapbox_style="open-street-map", height=600)
else:
    map_fig = go.Figure()
    map_fig.update_layout(title="No GPS Data Available", height=600)

# Create an initial empty vibration plot figure.
vib_empty_fig = go.Figure()
vib_empty_fig.update_layout(
    title="Vibration Signal",
    xaxis_title="Time (s)",
    yaxis_title="Acceleration"
)

print("Creation of interactive map finished.")

# Initialize Dash app.
app = dash.Dash(__name__)

app.layout = html.Div([
    html.Div([
        dcc.Graph(id="gps-map", figure=map_fig)
    ], style={'width': '48%', 'display': 'inline-block', 'vertical-align': 'top'}),
    html.Div([
        dcc.Graph(id="vibration-plot", figure=vib_empty_fig)
    ], style={'width': '48%', 'display': 'inline-block', 'vertical-align': 'top'})
])
print("Initialization of Dash app finished.")

# --------------------
# Callback to Update the Vibration Plot Based on Clicked GPS Point
# --------------------
@app.callback(
    Output('vibration-plot', 'figure'),
    [Input('gps-map', 'clickData')]
)
def update_vibration_plot(clickData):
    # If no point is selected, return the empty vibration figure.
    print("Clickdata:", clickData)

    if clickData is None:
        return vib_empty_fig

    # Retrieve the selected GPS point index from custom_data.
    #this line crashed, no 'customdata' in clickData: point_index = clickData['points'][0]['customdata'][0]
    #trying this:
    point_index = clickData['points'][0]['pointIndex']
    print("point_index: ", point_index)
    
    if segments.size == 0:
        empty_fig = go.Figure()
        empty_fig.update_layout(
            title="No Vibration Data Available",
            xaxis_title="Time (s)",
            yaxis_title="Acceleration"
        )
        return empty_fig

    # Map the GPS point to a vibration segment. If the selected index exceeds
    # the available number of segments, use the last segment as fallback.
    print("segments.shape[0] = ", segments.shape[0])
    if point_index < segments.shape[0]:
        selected_segment = segments[point_index]
    else:
        selected_segment = segments[-1]
        print("selected segment =segments[-1]")

    # Create a time axis for the selected segment.
    time_axis = np.arange(segment_length) * dt_vibration

    vib_fig = go.Figure()
    vib_fig.add_trace(go.Scatter(
        x=time_axis,
        y=selected_segment[:, 0],
        mode='lines',
        name='Vibration Channel 1'
    ))
    vib_fig.add_trace(go.Scatter(
        x=time_axis,
        y=selected_segment[:, 1],
        mode='lines',
        name='Vibration Channel 2'
    ))
    vib_fig.update_layout(
        title=f"Vibration Signal for GPS Point {point_index}",
        xaxis_title="Time (s)",
        yaxis_title="Acceleration"
    )
    return vib_fig

# ====================
# Run the Dash App
# ====================
if __name__ == "__main__":
    app.run_server(debug=True, port=8060)
# Out:
# Imports done, Tk initiated
# loading data in dataframes finished.
# creating GPS merged dataframes finished.
# merging vibration dataframes on timestamp finished.
# segment_length:  5000
# num_segments:  14400
# Segmented vibration data shape: (14400, 5000, 2)
# Data preprocessing and segmentation for vibration data finished.
# C:\Users\cajro\AppData\Local\Temp\ipykernel_30360\1927875034.py:199: DeprecationWarning: *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
#   map_fig = px.scatter_mapbox(
# Creation of interactive map finished.
# Initialization of Dash app finished.
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8060/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Clickdata: None
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 36259, 'pointIndex': 36259, 'lon': 15.0396036, 'lat': 60.7092746, 'bbox': {'x0': 436.7688903823258, 'x1': 438.7688903823258, 'y0': 406.7195626025635, 'y1': 408.7195626025635}}]}
# point_index:  36259
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 60819, 'pointIndex': 60819, 'lon': 15.4065698, 'lat': 60.5071033, 'bbox': {'x0': 517.8535706578502, 'x1': 519.8535706578502, 'y0': 344.9083819941396, 'y1': 346.9083819941396}}]}
# point_index:  60819
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 68533, 'pointIndex': 68533, 'lon': 15.1234215, 'lat': 60.5762743, 'bbox': {'x0': 397.19375904800876, 'x1': 399.19375904800876, 'y0': 284.971644208391, 'y1': 286.971644208391}}]}
# point_index:  68533
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 36173, 'pointIndex': 36173, 'lon': 15.0313331, 'lat': 60.7137338, 'bbox': {'x0': 357.9515351128602, 'x1': 359.9515351128602, 'y0': 165.48102560948047, 'y1': 167.48102560948047}}]}
# point_index:  36173
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 70039, 'pointIndex': 70039, 'lon': 15.0736755, 'lat': 60.6168901, 'bbox': {'x0': 375.9951751668775, 'x1': 377.9951751668775, 'y0': 249.71820949406495, 'y1': 251.71820949406495}}]}
# point_index:  70039
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 61696, 'pointIndex': 61696, 'lon': 15.3511188, 'lat': 60.5114746, 'bbox': {'x0': 494.22387832497793, 'x1': 496.22387832497793, 'y0': 341.12443585956976, 'y1': 343.12443585956976}}]}
# point_index:  61696
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 44383, 'pointIndex': 44383, 'lon': 15.4165358, 'lat': 60.500922, 'bbox': {'x0': 522.100446526446, 'x1': 524.100446526446, 'y0': 350.25825468708007, 'y1': 352.25825468708007}}]}
# point_index:  44383
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 68724, 'pointIndex': 68724, 'lon': 15.1099766, 'lat': 60.5861101, 'bbox': {'x0': 391.4643970807275, 'x1': 393.4643970807275, 'y0': 276.4384993682719, 'y1': 278.4384993682719}}]}
# point_index:  68724
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 68611, 'pointIndex': 68611, 'lon': 15.1190735, 'lat': 60.5807981, 'bbox': {'x0': 395.34091775994455, 'x1': 397.34091775994455, 'y0': 281.0472997378558, 'y1': 283.0472997378558}}]}
# point_index:  68611
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 36440, 'pointIndex': 36440, 'lon': 15.057031, 'lat': 60.7001173, 'bbox': {'x0': 369.9023470121362, 'x1': 371.9023470121362, 'y0': 180.34033359286212, 'y1': 182.34033359286212}}]}
# point_index:  36440
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 32113, 'pointIndex': 32113, 'lon': 15.0942103, 'lat': 60.8440465, 'bbox': {'x0': 478.7458019551777, 'x1': 480.7458019551777, 'y0': 311.17229324348625, 'y1': 313.17229324348625}}]}
# point_index:  32113
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 30830, 'pointIndex': 30830, 'lon': 15.1148678, 'lat': 60.8854343, 'bbox': {'x0': 487.5487156874367, 'x1': 489.5487156874367, 'y0': 274.94754286073737, 'y1': 276.94754286073737}}]}
# point_index:  30830
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 30207, 'pointIndex': 30207, 'lon': 15.0733563, 'lat': 60.8975706, 'bbox': {'x0': 469.8591524103686, 'x1': 471.8591524103686, 'y0': 264.31631500682545, 'y1': 266.31631500682545}}]}
# point_index:  30207
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 29671, 'pointIndex': 29671, 'lon': 15.042768, 'lat': 60.9159463, 'bbox': {'x0': 456.8243628125815, 'x1': 458.8243628125815, 'y0': 248.21175823590704, 'y1': 250.21175823590704}}]}
# point_index:  29671
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 29050, 'pointIndex': 29050, 'lon': 14.9778281, 'lat': 60.90588, 'bbox': {'x0': 429.15110431179875, 'x1': 431.15110431179875, 'y0': 257.0350643108111, 'y1': 259.0350643108111}}]}
# point_index:  29050
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28170, 'pointIndex': 28170, 'lon': 14.9193601, 'lat': 60.8828123, 'bbox': {'x0': 404.2357583068666, 'x1': 406.2357583068666, 'y0': 277.2438467588512, 'y1': 279.2438467588512}}]}
# point_index:  28170
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 27960, 'pointIndex': 27960, 'lon': 14.8890091, 'lat': 60.8820676, 'bbox': {'x0': 391.3020908888725, 'x1': 393.3020908888725, 'y0': 277.8960082043376, 'y1': 279.8960082043376}}]}
# point_index:  27960
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 153, 'pointIndex': 153, 'lon': 14.8223288, 'lat': 60.9124, 'bbox': {'x0': 362.8871845091028, 'x1': 364.8871845091028, 'y0': 251.32047648526256, 'y1': 253.32047648526256}}]}
# point_index:  153
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 27668, 'pointIndex': 27668, 'lon': 14.856127, 'lat': 60.893532, 'bbox': {'x0': 377.2898295002679, 'x1': 379.2898295002679, 'y0': 267.8545207445761, 'y1': 269.8545207445761}}]}
# point_index:  27668
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 27753, 'pointIndex': 27753, 'lon': 14.8644668, 'lat': 60.8889506, 'bbox': {'x0': 380.84372227258154, 'x1': 382.84372227258154, 'y0': 271.86772971266794, 'y1': 273.86772971266794}}]}
# point_index:  27753
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 27934, 'pointIndex': 27934, 'lon': 14.8854345, 'lat': 60.8820825, 'bbox': {'x0': 389.7788235318803, 'x1': 391.7788235318803, 'y0': 277.8829598701958, 'y1': 279.8829598701958}}]}
# point_index:  27934
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 27625, 'pointIndex': 27625, 'lon': 14.8521213, 'lat': 60.8957298, 'bbox': {'x0': 375.58285471932993, 'x1': 377.58285471932993, 'y0': 265.9290901060024, 'y1': 267.9290901060024}}]}
# point_index:  27625
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 27508, 'pointIndex': 27508, 'lon': 14.8433255, 'lat': 60.9014978, 'bbox': {'x0': 371.83464372545956, 'x1': 373.83464372545956, 'y0': 260.8752767936105, 'y1': 262.8752767936105}}]}
# point_index:  27508
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 26098, 'pointIndex': 26098, 'lon': 14.8249801, 'lat': 60.9113426, 'bbox': {'x0': 364.01700008109447, 'x1': 366.01700008109447, 'y0': 252.24733582822577, 'y1': 254.24733582822577}}]}
# point_index:  26098
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 22174, 'pointIndex': 22174, 'lon': 14.8013576, 'lat': 60.9197945, 'bbox': {'x0': 353.9505917722389, 'x1': 355.9505917722389, 'y0': 244.83800037473085, 'y1': 246.83800037473085}}]}
# point_index:  22174
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 710, 'pointIndex': 710, 'lon': 14.7577653, 'lat': 60.9334001, 'bbox': {'x0': 335.3743237683816, 'x1': 337.3743237683816, 'y0': 232.9065583748063, 'y1': 234.9065583748063}}]}
# point_index:  710
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 21740, 'pointIndex': 21740, 'lon': 14.7542988, 'lat': 60.9359135, 'bbox': {'x0': 333.8971217617156, 'x1': 335.8971217617156, 'y0': 230.70187242560917, 'y1': 232.70187242560917}}]}
# point_index:  21740
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 21476, 'pointIndex': 21476, 'lon': 14.7333231, 'lat': 60.9478031, 'bbox': {'x0': 324.95861141080894, 'x1': 326.95861141080894, 'y0': 220.2702802527755, 'y1': 222.2702802527755}}]}
# point_index:  21476
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1411, 'pointIndex': 1411, 'lon': 14.7085971, 'lat': 60.959245, 'bbox': {'x0': 314.42196152852404, 'x1': 316.42196152852404, 'y0': 210.22780701686582, 'y1': 212.22780701686582}}]}
# point_index:  1411
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 20901, 'pointIndex': 20901, 'lon': 14.6858361, 'lat': 60.9672881, 'bbox': {'x0': 304.72266977204686, 'x1': 306.72266977204686, 'y0': 203.1662739647582, 'y1': 205.1662739647582}}]}
# point_index:  20901
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 20807, 'pointIndex': 20807, 'lon': 14.6750978, 'lat': 60.9711723, 'bbox': {'x0': 300.1466887224998, 'x1': 302.1466887224998, 'y0': 199.7554559651112, 'y1': 201.7554559651112}}]}
# point_index:  20807
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 20730, 'pointIndex': 20730, 'lon': 14.6660776, 'lat': 60.9744296, 'bbox': {'x0': 296.30285270907103, 'x1': 298.30285270907103, 'y0': 196.8948140934346, 'y1': 198.8948140934346}}]}
# point_index:  20730
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 20648, 'pointIndex': 20648, 'lon': 14.656578, 'lat': 60.977818, 'bbox': {'x0': 292.25472688111995, 'x1': 294.25472688111995, 'y0': 193.91872591053448, 'y1': 195.91872591053448}}]}
# point_index:  20648
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 20479, 'pointIndex': 20479, 'lon': 14.6387528, 'lat': 60.9841251, 'bbox': {'x0': 284.65875941846105, 'x1': 286.65875941846105, 'y0': 188.37824998446519, 'y1': 190.37824998446519}}]}
# point_index:  20479
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 2290, 'pointIndex': 2290, 'lon': 14.6098386, 'lat': 60.9936238, 'bbox': {'x0': 272.3373648529606, 'x1': 274.3373648529606, 'y0': 180.03203572309206, 'y1': 182.03203572309206}}]}
# point_index:  2290
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 20230, 'pointIndex': 20230, 'lon': 14.6160198, 'lat': 60.992611, 'bbox': {'x0': 274.97139948258797, 'x1': 276.97139948258797, 'y0': 180.92207064175653, 'y1': 182.92207064175653}}]}
# point_index:  20230
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 20117, 'pointIndex': 20117, 'lon': 14.6037886, 'lat': 60.9966216, 'bbox': {'x0': 269.7592393256606, 'x1': 271.7592393256606, 'y0': 177.39744339236427, 'y1': 179.39744339236427}}]}
# point_index:  20117
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 19928, 'pointIndex': 19928, 'lon': 14.5871793, 'lat': 61.0001348, 'bbox': {'x0': 262.68141117353764, 'x1': 264.68141117353764, 'y0': 174.30957946961834, 'y1': 176.30957946961834}}]}
# point_index:  19928
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 19757, 'pointIndex': 19757, 'lon': 14.5796221, 'lat': 61.0035226, 'bbox': {'x0': 259.46101278758476, 'x1': 261.46101278758476, 'y0': 171.3316100970975, 'y1': 173.3316100970975}}]}
# point_index:  19757
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 19406, 'pointIndex': 19406, 'lon': 14.5669493, 'lat': 61.0085451, 'bbox': {'x0': 254.06067077399246, 'x1': 256.06067077399246, 'y0': 166.91610976705948, 'y1': 168.91610976705948}}]}
# point_index:  19406
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 19300, 'pointIndex': 19300, 'lon': 14.5637095, 'lat': 61.0088368, 'bbox': {'x0': 252.68007390072185, 'x1': 254.68007390072185, 'y0': 166.6596420242259, 'y1': 168.6596420242259}}]}
# point_index:  19300
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 17716, 'pointIndex': 17716, 'lon': 14.5497123, 'lat': 61.0087353, 'bbox': {'x0': 246.71535677169524, 'x1': 248.71535677169524, 'y0': 166.74888286711206, 'y1': 168.74888286711206}}]}
# point_index:  17716
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 11766, 'pointIndex': 11766, 'lon': 14.5426471, 'lat': 61.0053038, 'bbox': {'x0': 243.7046175195584, 'x1': 245.7046175195584, 'y0': 169.76575887559187, 'y1': 171.76575887559187}}]}
# point_index:  11766
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 21374, 'pointIndex': 21374, 'lon': 14.7276003, 'lat': 60.9508228, 'bbox': {'x0': 322.519917730242, 'x1': 324.519917730242, 'y0': 217.62026203436747, 'y1': 219.62026203436747}}]}
# point_index:  21374
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1105, 'pointIndex': 1105, 'lon': 14.7296193, 'lat': 60.9494465, 'bbox': {'x0': 323.3802872243855, 'x1': 325.3802872243855, 'y0': 218.82810196565492, 'y1': 220.82810196565492}}]}
# point_index:  1105
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 21878, 'pointIndex': 21878, 'lon': 14.7686781, 'lat': 60.9296726, 'bbox': {'x0': 340.02466562857467, 'x1': 342.02466562857467, 'y0': 236.1758993893862, 'y1': 238.1758993893862}}]}
# point_index:  21878
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 36223, 'pointIndex': 36223, 'lon': 15.0361218, 'lat': 60.7111435, 'bbox': {'x0': 453.99217473333556, 'x1': 455.99217473333556, 'y0': 427.17965502235154, 'y1': 429.17965502235154}}]}
# point_index:  36223
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 70655, 'pointIndex': 70655, 'lon': 15.1021038, 'lat': 60.655136, 'bbox': {'x0': 482.10951002952123, 'x1': 484.10951002952123, 'y0': 475.923406493516, 'y1': 477.923406493516}}]}
# point_index:  70655
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 70251, 'pointIndex': 70251, 'lon': 15.0896936, 'lat': 60.6295853, 'bbox': {'x0': 476.82107144789325, 'x1': 478.82107144789325, 'y0': 498.1322269594149, 'y1': 500.1322269594149}}]}
# point_index:  70251
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34096, 'pointIndex': 34096, 'lon': 15.0226998, 'lat': 60.787382, 'bbox': {'x0': 448.27257129080476, 'x1': 450.27257129080476, 'y0': 360.69201125240045, 'y1': 362.69201125240045}}]}
# point_index:  34096
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34213, 'pointIndex': 34213, 'lon': 15.0196238, 'lat': 60.7792586, 'bbox': {'x0': 446.9617755681749, 'x1': 448.9617755681749, 'y0': 367.78395815316645, 'y1': 369.78395815316645}}]}
# point_index:  34213
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34378, 'pointIndex': 34378, 'lon': 15.016891, 'lat': 60.7676173, 'bbox': {'x0': 445.79722987543494, 'x1': 447.79722987543494, 'y0': 377.9439932761448, 'y1': 379.9439932761448}}]}
# point_index:  34378
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34436, 'pointIndex': 34436, 'lon': 15.0174275, 'lat': 60.7633556, 'bbox': {'x0': 446.0258520812861, 'x1': 448.0258520812861, 'y0': 381.66250272831394, 'y1': 383.66250272831394}}]}
# point_index:  34436
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34501, 'pointIndex': 34501, 'lon': 15.0181558, 'lat': 60.7587891, 'bbox': {'x0': 446.3362072584057, 'x1': 448.3362072584057, 'y0': 385.6464143975623, 'y1': 387.6464143975623}}]}
# point_index:  34501
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34916, 'pointIndex': 34916, 'lon': 15.0019818, 'lat': 60.7412238, 'bbox': {'x0': 439.4438763032948, 'x1': 441.4438763032948, 'y0': 400.9654707223532, 'y1': 402.9654707223532}}]}
# point_index:  34916
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 35021, 'pointIndex': 35021, 'lon': 15.0015915, 'lat': 60.7374563, 'bbox': {'x0': 439.2775552465329, 'x1': 441.2775552465329, 'y0': 404.25009239406455, 'y1': 406.25009239406455}}]}
# point_index:  35021
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 35710, 'pointIndex': 35710, 'lon': 15.0046965, 'lat': 60.7329068, 'bbox': {'x0': 440.60070892625623, 'x1': 442.60070892625623, 'y0': 408.21597183025665, 'y1': 410.21597183025665}}]}
# point_index:  35710
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 35863, 'pointIndex': 35863, 'lon': 15.0087636, 'lat': 60.7272251, 'bbox': {'x0': 442.33384848527965, 'x1': 444.33384848527965, 'y0': 413.1680209943995, 'y1': 415.1680209943995}}]}
# point_index:  35863
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 35881, 'pointIndex': 35881, 'lon': 15.0096853, 'lat': 60.7264371, 'bbox': {'x0': 442.7266184519681, 'x1': 444.7266184519681, 'y0': 413.8547558971636, 'y1': 415.8547558971636}}]}
# point_index:  35881
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 35891, 'pointIndex': 35891, 'lon': 15.0103266, 'lat': 60.7260715, 'bbox': {'x0': 442.99989975786633, 'x1': 444.99989975786633, 'y0': 414.17336728240525, 'y1': 416.17336728240525}}]}
# point_index:  35891
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 35901, 'pointIndex': 35901, 'lon': 15.011043, 'lat': 60.725736, 'bbox': {'x0': 443.3051839112171, 'x1': 445.3051839112171, 'y0': 414.4657440687219, 'y1': 416.4657440687219}}]}
# point_index:  35901
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34004, 'pointIndex': 34004, 'lon': 15.0234956, 'lat': 60.7929451, 'bbox': {'x0': 460.0086272599205, 'x1': 462.0086272599205, 'y0': 294.07803359613536, 'y1': 296.07803359613536}}]}
# point_index:  34004
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34020, 'pointIndex': 34020, 'lon': 15.0233491, 'lat': 60.7919925, 'bbox': {'x0': 459.5744562847274, 'x1': 461.5744562847274, 'y0': 299.86347773827254, 'y1': 301.86347773827254}}]}
# point_index:  34020
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34034, 'pointIndex': 34034, 'lon': 15.023238, 'lat': 60.7911853, 'bbox': {'x0': 459.24519761346636, 'x1': 461.24519761346636, 'y0': 304.76572656333445, 'y1': 306.76572656333445}}]}
# point_index:  34034
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34064, 'pointIndex': 34064, 'lon': 15.0229773, 'lat': 60.7894143, 'bbox': {'x0': 458.4725807311989, 'x1': 460.4725807311989, 'y0': 315.5208471021009, 'y1': 317.5208471021009}}]}
# point_index:  34064
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34095, 'pointIndex': 34095, 'lon': 15.0227086, 'lat': 60.7874483, 'bbox': {'x0': 457.67625485355893, 'x1': 459.67625485355893, 'y0': 327.4594884005804, 'y1': 329.4594884005804}}]}
# point_index:  34095
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34112, 'pointIndex': 34112, 'lon': 15.0225351, 'lat': 60.7863101, 'bbox': {'x0': 457.16206601943287, 'x1': 459.16206601943287, 'y0': 334.37093459963796, 'y1': 336.37093459963796}}]}
# point_index:  34112
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34139, 'pointIndex': 34139, 'lon': 15.0222046, 'lat': 60.7844723, 'bbox': {'x0': 456.1825881536991, 'x1': 458.1825881536991, 'y0': 345.5300155491583, 'y1': 347.5300155491583}}]}
# point_index:  34139
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34155, 'pointIndex': 34155, 'lon': 15.0217418, 'lat': 60.7833458, 'bbox': {'x0': 454.81102277939283, 'x1': 456.81102277939283, 'y0': 352.36978223673884, 'y1': 354.36978223673884}}]}
# point_index:  34155
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34196, 'pointIndex': 34196, 'lon': 15.0202146, 'lat': 60.7804911, 'bbox': {'x0': 450.2849755888893, 'x1': 452.2849755888893, 'y0': 369.70157901616324, 'y1': 371.70157901616324}}]}
# point_index:  34196
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34237, 'pointIndex': 34237, 'lon': 15.0188255, 'lat': 60.7775103, 'bbox': {'x0': 446.1682049284852, 'x1': 448.1682049284852, 'y0': 387.7973216197793, 'y1': 389.7973216197793}}]}
# point_index:  34237
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34314, 'pointIndex': 34314, 'lon': 15.0166605, 'lat': 60.77211, 'bbox': {'x0': 439.7519580926214, 'x1': 441.7519580926214, 'y0': 420.57699932120147, 'y1': 422.57699932120147}}]}
# point_index:  34314
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34330, 'pointIndex': 34330, 'lon': 15.0166155, 'lat': 60.7709525, 'bbox': {'x0': 439.6185949944315, 'x1': 441.6185949944315, 'y0': 427.60227497645786, 'y1': 429.60227497645786}}]}
# point_index:  34330
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34349, 'pointIndex': 34349, 'lon': 15.0167106, 'lat': 60.7696151, 'bbox': {'x0': 439.90043567532587, 'x1': 441.90043567532587, 'y0': 435.7191113341422, 'y1': 437.7191113341422}}]}
# point_index:  34349
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34360, 'pointIndex': 34360, 'lon': 15.01681, 'lat': 60.7688291, 'bbox': {'x0': 440.1950199411029, 'x1': 442.1950199411029, 'y0': 440.48927890809756, 'y1': 442.48927890809756}}]}
# point_index:  34360
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 34382, 'pointIndex': 34382, 'lon': 15.0169101, 'lat': 60.7673395, 'bbox': {'x0': 440.49167874389224, 'x1': 442.49167874389224, 'y0': 449.5292146174681, 'y1': 451.5292146174681}}]}
# point_index:  34382
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 31803, 'pointIndex': 31803, 'lon': 15.094815, 'lat': 60.8608843, 'bbox': {'x0': 575.2412287400829, 'x1': 577.2412287400829, 'y0': 278.89269070346205, 'y1': 280.89269070346205}}]}
# point_index:  31803
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 31715, 'pointIndex': 31715, 'lon': 15.0962321, 'lat': 60.8653546, 'bbox': {'x0': 579.4409808836285, 'x1': 581.4409808836285, 'y0': 251.68309456162035, 'y1': 253.68309456162035}}]}
# point_index:  31715
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 31639, 'pointIndex': 31639, 'lon': 15.0976833, 'lat': 60.8690745, 'bbox': {'x0': 583.7417926195121, 'x1': 585.7417926195121, 'y0': 229.03809169388953, 'y1': 231.03809169388953}}]}
# point_index:  31639
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 30145, 'pointIndex': 30145, 'lon': 15.0662273, 'lat': 60.8982225, 'bbox': {'x0': 506.51802338276593, 'x1': 508.51802338276593, 'y0': 376.5073827265274, 'y1': 378.5073827265274}}]}
# point_index:  30145
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 30103, 'pointIndex': 30103, 'lon': 15.0621955, 'lat': 60.8987363, 'bbox': {'x0': 494.5692825085587, 'x1': 496.5692825085587, 'y0': 373.3765440533085, 'y1': 375.3765440533085}}]}
# point_index:  30103
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 29033, 'pointIndex': 29033, 'lon': 14.9761661, 'lat': 60.9062058, 'bbox': {'x0': 239.61045316268527, 'x1': 241.61045316268527, 'y0': 327.85547169309757, 'y1': 329.85547169309757}}]}
# point_index:  29033
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 29007, 'pointIndex': 29007, 'lon': 14.9737293, 'lat': 60.9067583, 'bbox': {'x0': 232.38869321374665, 'x1': 234.38869321374665, 'y0': 324.48796966416495, 'y1': 326.48796966416495}}]}
# point_index:  29007
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28994, 'pointIndex': 28994, 'lon': 14.9725881, 'lat': 60.9070508, 'bbox': {'x0': 229.00660504329772, 'x1': 231.00660504329772, 'y0': 322.7051508465456, 'y1': 324.7051508465456}}]}
# point_index:  28994
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28967, 'pointIndex': 28967, 'lon': 14.9706708, 'lat': 60.9079368, 'bbox': {'x0': 223.32444797243392, 'x1': 225.32444797243392, 'y0': 317.30478617009663, 'y1': 319.30478617009663}}]}
# point_index:  28967
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28925, 'pointIndex': 28925, 'lon': 14.969171, 'lat': 60.9097125, 'bbox': {'x0': 218.87960409058465, 'x1': 220.87960409058465, 'y0': 306.48105266406424, 'y1': 308.48105266406424}}]}
# point_index:  28925
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28913, 'pointIndex': 28913, 'lon': 14.9678245, 'lat': 60.9099233, 'bbox': {'x0': 214.88908382994788, 'x1': 216.88908382994788, 'y0': 305.1960866709077, 'y1': 307.1960866709077}}]}
# point_index:  28913
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28858, 'pointIndex': 28858, 'lon': 14.962631, 'lat': 60.908328, 'bbox': {'x0': 199.4975004849926, 'x1': 201.4975004849926, 'y0': 314.92028844985697, 'y1': 316.92028844985697}}]}
# point_index:  28858
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28478, 'pointIndex': 28478, 'lon': 14.9588521, 'lat': 60.8828615, 'bbox': {'x0': 443.29826025660077, 'x1': 445.29826025660077, 'y0': 380.0863006181187, 'y1': 382.0863006181187}}]}
# point_index:  28478
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28399, 'pointIndex': 28399, 'lon': 14.9513751, 'lat': 60.8823851, 'bbox': {'x0': 421.13924058410856, 'x1': 423.13924058410856, 'y0': 382.9878000687985, 'y1': 384.9878000687985}}]}
# point_index:  28399
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28185, 'pointIndex': 28185, 'lon': 14.921461, 'lat': 60.8829315, 'bbox': {'x0': 332.48508378484894, 'x1': 334.48508378484894, 'y0': 379.65996413557303, 'y1': 381.65996413557303}}]}
# point_index:  28185
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28115, 'pointIndex': 28115, 'lon': 14.911452, 'lat': 60.8823915, 'bbox': {'x0': 302.82216711999877, 'x1': 304.82216711999877, 'y0': 382.9488213541489, 'y1': 384.9488213541489}}]}
# point_index:  28115
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 27818, 'pointIndex': 27818, 'lon': 14.8706743, 'lat': 60.8854888, 'bbox': {'x0': 181.97238023981214, 'x1': 183.97238023981214, 'y0': 364.08403314725746, 'y1': 366.08403314725746}}]}
# point_index:  27818
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 27476, 'pointIndex': 27476, 'lon': 14.8407521, 'lat': 60.902756, 'bbox': {'x0': 360.2942180958059, 'x1': 362.2942180958059, 'y0': 327.88077376399724, 'y1': 329.88077376399724}}]}
# point_index:  27476
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 53, 'pointIndex': 53, 'lon': 14.8329978, 'lat': 60.9075421, 'bbox': {'x0': 337.3133853759084, 'x1': 339.3133853759084, 'y0': 298.7105879563188, 'y1': 300.7105879563188}}]}
# point_index:  53
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 27342, 'pointIndex': 27342, 'lon': 14.8323291, 'lat': 60.907575, 'bbox': {'x0': 458.33160978593526, 'x1': 460.33160978593526, 'y0': 368.5100548458005, 'y1': 370.5100548458005}}]}
# point_index:  27342
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 27311, 'pointIndex': 27311, 'lon': 14.8307551, 'lat': 60.9083355, 'bbox': {'x0': 453.66686497321206, 'x1': 455.66686497321206, 'y0': 363.87457314937836, 'y1': 365.87457314937836}}]}
# point_index:  27311
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 27365, 'pointIndex': 27365, 'lon': 14.833622, 'lat': 60.9068683, 'bbox': {'x0': 462.1632797784275, 'x1': 464.1632797784275, 'y0': 372.81750985469137, 'y1': 374.81750985469137}}]}
# point_index:  27365
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 27362, 'pointIndex': 27362, 'lon': 14.8334626, 'lat': 60.906958, 'bbox': {'x0': 461.69087804830264, 'x1': 463.69087804830264, 'y0': 372.2707786031186, 'y1': 374.2707786031186}}]}
# point_index:  27362
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 27338, 'pointIndex': 27338, 'lon': 14.8321133, 'lat': 60.9076855, 'bbox': {'x0': 457.69205963923815, 'x1': 459.69205963923815, 'y0': 367.83653018351583, 'y1': 369.83653018351583}}]}
# point_index:  27338
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 27375, 'pointIndex': 27375, 'lon': 14.8341415, 'lat': 60.9065546, 'bbox': {'x0': 463.70288265650237, 'x1': 465.70288265650237, 'y0': 374.7295333615371, 'y1': 376.7295333615371}}]}
# point_index:  27375
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 22792, 'pointIndex': 22792, 'lon': 14.823065, 'lat': 60.9113993, 'bbox': {'x0': 506.48459520226436, 'x1': 508.48459520226436, 'y0': 411.0508929657558, 'y1': 413.0508929657558}}]}
# point_index:  22792
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 149, 'pointIndex': 149, 'lon': 14.8227405, 'lat': 60.912218, 'bbox': {'x0': 503.2770521553736, 'x1': 505.2770521553736, 'y0': 394.4049818674723, 'y1': 396.4049818674723}}]}
# point_index:  149
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 159, 'pointIndex': 159, 'lon': 14.8217003, 'lat': 60.9126815, 'bbox': {'x0': 492.9951221776387, 'x1': 494.9951221776387, 'y0': 384.98085217816487, 'y1': 386.98085217816487}}]}
# point_index:  159
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 166, 'pointIndex': 166, 'lon': 14.8210113, 'lat': 60.9129725, 'bbox': {'x0': 486.1846532730829, 'x1': 488.1846532730829, 'y0': 379.0640146416331, 'y1': 381.0640146416331}}]}
# point_index:  166
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 182, 'pointIndex': 182, 'lon': 14.8194135, 'lat': 60.913681, 'bbox': {'x0': 470.3910869216162, 'x1': 472.3910869216162, 'y0': 364.6580176518077, 'y1': 366.6580176518077}}]}
# point_index:  182
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 200, 'pointIndex': 200, 'lon': 14.8175263, 'lat': 60.9145186, 'bbox': {'x0': 451.7369259387728, 'x1': 453.7369259387728, 'y0': 347.6266051631125, 'y1': 349.6266051631125}}]}
# point_index:  200
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 210, 'pointIndex': 210, 'lon': 14.8164573, 'lat': 60.9149996, 'bbox': {'x0': 441.17032033791617, 'x1': 443.17032033791617, 'y0': 337.8459474841753, 'y1': 339.8459474841753}}]}
# point_index:  210
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 221, 'pointIndex': 221, 'lon': 14.815292, 'lat': 60.9155066, 'bbox': {'x0': 429.65183062099277, 'x1': 431.65183062099277, 'y0': 327.5364458093568, 'y1': 329.5364458093568}}]}
# point_index:  221
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 235, 'pointIndex': 235, 'lon': 14.8138205, 'lat': 60.9161248, 'bbox': {'x0': 415.1066854927275, 'x1': 417.1066854927275, 'y0': 314.9655455244912, 'y1': 316.9655455244912}}]}
# point_index:  235
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 254, 'pointIndex': 254, 'lon': 14.8117936, 'lat': 60.917005, 'bbox': {'x0': 565.0716502083673, 'x1': 567.0716502083673, 'y0': 382.06653783188926, 'y1': 384.06653783188926}}]}
# point_index:  254
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 276, 'pointIndex': 276, 'lon': 14.8094701, 'lat': 60.9179726, 'bbox': {'x0': 542.1048512239305, 'x1': 544.1048512239305, 'y0': 362.389666720799, 'y1': 364.389666720799}}]}
# point_index:  276
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 289, 'pointIndex': 289, 'lon': 14.8079385, 'lat': 60.9184855, 'bbox': {'x0': 526.9656434237011, 'x1': 528.9656434237011, 'y0': 351.95921856808286, 'y1': 353.95921856808286}}]}
# point_index:  289
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 462, 'pointIndex': 462, 'lon': 14.7862501, 'lat': 60.9248355, 'bbox': {'x0': 170.7486394163162, 'x1': 172.7486394163162, 'y0': 243.75764849223788, 'y1': 245.75764849223788}}]}
# point_index:  462
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 22024, 'pointIndex': 22024, 'lon': 14.7854028, 'lat': 60.9247021, 'bbox': {'x0': 150.00910474762082, 'x1': 152.00910474762082, 'y0': 250.47687447146765, 'y1': 252.47687447146765}}]}
# point_index:  22024
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 469, 'pointIndex': 469, 'lon': 14.78522, 'lat': 60.9249253, 'bbox': {'x0': 145.5346719174158, 'x1': 147.5346719174158, 'y0': 239.2344955202133, 'y1': 241.2344955202133}}]}
# point_index:  469
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 22024, 'pointIndex': 22024, 'lon': 14.7854028, 'lat': 60.9247021, 'bbox': {'x0': 386.0091051775312, 'x1': 388.0091051775312, 'y0': 328.4768742614322, 'y1': 330.4768742614322}}]}
# point_index:  22024
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 472, 'pointIndex': 472, 'lon': 14.7847785, 'lat': 60.9249758, 'bbox': {'x0': 370.72798692839484, 'x1': 372.72798692839484, 'y0': 314.6908457752258, 'y1': 316.6908457752258}}]}
# point_index:  472
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 478, 'pointIndex': 478, 'lon': 14.7838998, 'lat': 60.925061, 'bbox': {'x0': 349.21986806430516, 'x1': 351.21986806430516, 'y0': 310.39937247094656, 'y1': 312.39937247094656}}]}
# point_index:  478
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 485, 'pointIndex': 485, 'lon': 14.782883, 'lat': 60.9251128, 'bbox': {'x0': 324.33144737425306, 'x1': 326.33144737425306, 'y0': 307.79023168389756, 'y1': 309.79023168389756}}]}
# point_index:  485
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 490, 'pointIndex': 490, 'lon': 14.7821538, 'lat': 60.9251401, 'bbox': {'x0': 306.4826704592932, 'x1': 308.4826704592932, 'y0': 306.4151422651987, 'y1': 308.4151422651987}}]}
# point_index:  490
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 21995, 'pointIndex': 21995, 'lon': 14.7813741, 'lat': 60.9252213, 'bbox': {'x0': 287.3977947590843, 'x1': 289.3977947590843, 'y0': 302.32512574612144, 'y1': 304.32512574612144}}]}
# point_index:  21995
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 21990, 'pointIndex': 21990, 'lon': 14.7807085, 'lat': 60.9253693, 'bbox': {'x0': 271.1057679971059, 'x1': 273.1057679971059, 'y0': 294.8703890141987, 'y1': 296.8703890141987}}]}
# point_index:  21990
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 21961, 'pointIndex': 21961, 'lon': 14.777134, 'lat': 60.926473, 'bbox': {'x0': 346.61200387591407, 'x1': 348.61200387591407, 'y0': 357.2761012599582, 'y1': 359.2761012599582}}]}
# point_index:  21961
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 21927, 'pointIndex': 21927, 'lon': 14.7735096, 'lat': 60.9279236, 'bbox': {'x0': 399.89682738061936, 'x1': 401.89682738061936, 'y0': 381.2052423579352, 'y1': 383.2052423579352}}]}
# point_index:  21927
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 21924, 'pointIndex': 21924, 'lon': 14.7731896, 'lat': 60.9280458, 'bbox': {'x0': 392.0641222075811, 'x1': 394.0641222075811, 'y0': 375.0495278979105, 'y1': 377.0495278979105}}]}
# point_index:  21924
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 579, 'pointIndex': 579, 'lon': 14.772219, 'lat': 60.9278945, 'bbox': {'x0': 368.3065483267345, 'x1': 370.3065483267345, 'y0': 382.67112505246723, 'y1': 384.67112505246723}}]}
# point_index:  579
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 584, 'pointIndex': 584, 'lon': 14.7716876, 'lat': 60.9280818, 'bbox': {'x0': 355.29936229690674, 'x1': 357.29936229690674, 'y0': 373.2360559588387, 'y1': 375.2360559588387}}]}
# point_index:  584
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 638, 'pointIndex': 638, 'lon': 14.7651511, 'lat': 60.930401, 'bbox': {'x0': 317.3041207669273, 'x1': 319.3041207669273, 'y0': 359.40384422635276, 'y1': 361.40384422635276}}]}
# point_index:  638
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 656, 'pointIndex': 656, 'lon': 14.7628281, 'lat': 60.9309875, 'bbox': {'x0': 323.5388134441679, 'x1': 325.5388134441679, 'y0': 384.8569238159392, 'y1': 386.8569238159392}}]}
# point_index:  656
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 663, 'pointIndex': 663, 'lon': 14.7622535, 'lat': 60.9313743, 'bbox': {'x0': 309.47421221581715, 'x1': 311.47421221581715, 'y0': 365.3702683902922, 'y1': 367.3702683902922}}]}
# point_index:  663
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 697, 'pointIndex': 697, 'lon': 14.7590091, 'lat': 60.9328165, 'bbox': {'x0': 230.0603726341611, 'x1': 232.0603726341611, 'y0': 292.7113712102648, 'y1': 294.7113712102648}}]}
# point_index:  697
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 770, 'pointIndex': 770, 'lon': 14.7518538, 'lat': 60.9367351, 'bbox': {'x0': 315.9186373892285, 'x1': 317.9186373892285, 'y0': 262.27334610810357, 'y1': 264.27334610810357}}]}
# point_index:  770
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 818, 'pointIndex': 818, 'lon': 14.7485436, 'lat': 60.9391681, 'bbox': {'x0': 405.59577641260057, 'x1': 407.59577641260057, 'y0': 383.1248219259202, 'y1': 385.1248219259202}}]}
# point_index:  818
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 793, 'pointIndex': 793, 'lon': 14.7504128, 'lat': 60.937893, 'bbox': {'x0': 451.348565511098, 'x1': 453.348565511098, 'y0': 447.3781044687544, 'y1': 449.3781044687544}}]}
# point_index:  793
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 927, 'pointIndex': 927, 'lon': 14.7395458, 'lat': 60.9440463, 'bbox': {'x0': 332.03850831304277, 'x1': 334.03850831304277, 'y0': 317.23126744732025, 'y1': 319.23126744732025}}]}
# point_index:  927
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1045, 'pointIndex': 1045, 'lon': 14.7324681, 'lat': 60.947894, 'bbox': {'x0': 294.7962041521829, 'x1': 296.7962041521829, 'y0': 344.29735069464124, 'y1': 346.29735069464124}}]}
# point_index:  1045
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1207, 'pointIndex': 1207, 'lon': 14.7249258, 'lat': 60.9518956, 'bbox': {'x0': 330.1817910383618, 'x1': 332.1817910383618, 'y0': 340.58160838778053, 'y1': 342.58160838778053}}]}
# point_index:  1207
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1264, 'pointIndex': 1264, 'lon': 14.721833, 'lat': 60.9534828, 'bbox': {'x0': 254.47869553187536, 'x1': 256.47869553187536, 'y0': 260.56577964396706, 'y1': 262.56577964396706}}]}
# point_index:  1264
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1372, 'pointIndex': 1372, 'lon': 14.7129106, 'lat': 60.9578705, 'bbox': {'x0': 254.17819237330602, 'x1': 256.17819237330605, 'y0': 358.53681675365993, 'y1': 360.53681675365993}}]}
# point_index:  1372
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1462, 'pointIndex': 1462, 'lon': 14.7025113, 'lat': 60.9611413, 'bbox': {'x0': 348.6186015832992, 'x1': 350.6186015832992, 'y0': 274.60999543856065, 'y1': 276.60999543856065}}]}
# point_index:  1462
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1528, 'pointIndex': 1528, 'lon': 14.6945436, 'lat': 60.9634536, 'bbox': {'x0': 429.5915861894214, 'x1': 431.5915861894214, 'y0': 329.0043464902848, 'y1': 331.0043464902848}}]}
# point_index:  1528
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1597, 'pointIndex': 1597, 'lon': 14.68699, 'lat': 60.9659856, 'bbox': {'x0': 471.7005807778192, 'x1': 473.7005807778192, 'y0': 321.3098487502053, 'y1': 323.3098487502053}}]}
# point_index:  1597
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1637, 'pointIndex': 1637, 'lon': 14.6826541, 'lat': 60.9675648, 'bbox': {'x0': 365.5698733912574, 'x1': 367.5698733912574, 'y0': 241.66206650204128, 'y1': 243.66206650204128}}]}
# point_index:  1637
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1681, 'pointIndex': 1681, 'lon': 14.6777058, 'lat': 60.9694103, 'bbox': {'x0': 465.4493268134102, 'x1': 467.4493268134102, 'y0': 368.57829177266075, 'y1': 370.57829177266075}}]}
# point_index:  1681
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1693, 'pointIndex': 1693, 'lon': 14.6763188, 'lat': 60.9699636, 'bbox': {'x0': 431.49944532485233, 'x1': 433.49944532485233, 'y0': 340.6697601640035, 'y1': 342.6697601640035}}]}
# point_index:  1693
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1696, 'pointIndex': 1696, 'lon': 14.675963, 'lat': 60.9701141, 'bbox': {'x0': 422.7904562601967, 'x1': 424.7904562601967, 'y0': 333.0784345006186, 'y1': 335.0784345006186}}]}
# point_index:  1696
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1699, 'pointIndex': 1699, 'lon': 14.675612, 'lat': 60.9702608, 'bbox': {'x0': 414.1989577732389, 'x1': 416.1989577732389, 'y0': 325.6787489274192, 'y1': 327.6787489274192}}]}
# point_index:  1699
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1705, 'pointIndex': 1705, 'lon': 14.674913, 'lat': 60.9705498, 'bbox': {'x0': 397.0893924084921, 'x1': 399.0893924084921, 'y0': 311.10121803586446, 'y1': 313.10121803586446}}]}
# point_index:  1705
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1709, 'pointIndex': 1709, 'lon': 14.6744365, 'lat': 60.9707326, 'bbox': {'x0': 385.42600485937936, 'x1': 387.42600485937936, 'y0': 301.8804830320298, 'y1': 303.8804830320298}}]}
# point_index:  1709
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1774, 'pointIndex': 1774, 'lon': 14.667382, 'lat': 60.973267, 'bbox': {'x0': 444.4885005209181, 'x1': 446.4885005209181, 'y0': 393.9005310266737, 'y1': 395.9005310266737}}]}
# point_index:  1774
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1784, 'pointIndex': 1784, 'lon': 14.6662636, 'lat': 60.9736831, 'bbox': {'x0': 417.1131959385342, 'x1': 419.1131959385342, 'y0': 372.9098865879906, 'y1': 374.9098865879906}}]}
# point_index:  1784
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1790, 'pointIndex': 1790, 'lon': 14.6655926, 'lat': 60.9739338, 'bbox': {'x0': 400.6889922762674, 'x1': 402.6889922762674, 'y0': 360.26290330659776, 'y1': 362.26290330659776}}]}
# point_index:  1790
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1800, 'pointIndex': 1800, 'lon': 14.664459, 'lat': 60.9743565, 'bbox': {'x0': 372.9416341970837, 'x1': 374.9416341970837, 'y0': 338.9388648282914, 'y1': 340.9388648282914}}]}
# point_index:  1800
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1871, 'pointIndex': 1871, 'lon': 14.6564668, 'lat': 60.97732, 'bbox': {'x0': 479.31492719423204, 'x1': 481.31492719423204, 'y0': 399.4305761424322, 'y1': 401.4305761424322}}]}
# point_index:  1871
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 1904, 'pointIndex': 1904, 'lon': 14.6527223, 'lat': 60.97864, 'bbox': {'x0': 501.6600383864509, 'x1': 503.6600383864509, 'y0': 447.8322168917883, 'y1': 449.8322168917883}}]}
# point_index:  1904
# segments.shape[0] =  14400
# ...
# point_index:  94
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 12, 'pointIndex': 12, 'lon': 14.8367453, 'lat': 60.9054368, 'bbox': {'x0': 362.24333868405176, 'x1': 364.24333868405176, 'y0': 322.1208646100665, 'y1': 324.1208646100665}}]}
# point_index:  12
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 27927, 'pointIndex': 27927, 'lon': 14.8844553, 'lat': 60.8821556, 'bbox': {'x0': 395.88825606240164, 'x1': 397.88825606240164, 'y0': 289.2247990464407, 'y1': 291.2247990464407}}]}
# point_index:  27927
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28043, 'pointIndex': 28043, 'lon': 14.9007665, 'lat': 60.8822181, 'bbox': {'x0': 420.1408209566086, 'x1': 422.1408209566086, 'y0': 260.08093712746154, 'y1': 262.08093712746154}}]}
# point_index:  28043
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 29060, 'pointIndex': 29060, 'lon': 14.9788398, 'lat': 60.9056698, 'bbox': {'x0': 394.8755494647556, 'x1': 396.8755494647556, 'y0': 135.97851062719783, 'y1': 137.97851062719783}}]}
# point_index:  29060
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 30126, 'pointIndex': 30126, 'lon': 15.064332, 'lat': 60.8984828, 'bbox': {'x0': 342.56766680280367, 'x1': 344.56766680280367, 'y0': 273.1823236982974, 'y1': 275.1823236982974}}]}
# point_index:  30126
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 31509, 'pointIndex': 31509, 'lon': 15.1058858, 'lat': 60.8744623, 'bbox': {'x0': 191.00065197878413, 'x1': 193.00065197878413, 'y0': 288.70692460395037, 'y1': 290.70692460395037}}]}
# point_index:  31509
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 32648, 'pointIndex': 32648, 'lon': 15.0570731, 'lat': 60.8279278, 'bbox': {'x0': 367.73862135117014, 'x1': 369.73862135117014, 'y0': 367.4777255324144, 'y1': 369.4777255324144}}]}
# point_index:  32648
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 32511, 'pointIndex': 32511, 'lon': 15.0704885, 'lat': 60.8315886, 'bbox': {'x0': 528.6447462475489, 'x1': 530.6447462475489, 'y0': 366.54601661439926, 'y1': 368.54601661439926}}]}
# point_index:  32511
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 32668, 'pointIndex': 32668, 'lon': 15.0554676, 'lat': 60.826979, 'bbox': {'x0': 341.1809560775757, 'x1': 343.1809560775757, 'y0': 382.5995412221031, 'y1': 384.5995412221031}}]}
# point_index:  32668
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 33577, 'pointIndex': 33577, 'lon': 15.011578, 'lat': 60.8151545, 'bbox': {'x0': 337.98472815165445, 'x1': 339.98472815165445, 'y0': 339.7987935179756, 'y1': 341.7987935179756}}]}
# point_index:  33577
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 33935, 'pointIndex': 33935, 'lon': 15.0213528, 'lat': 60.7967696, 'bbox': {'x0': 453.9194283364311, 'x1': 455.9194283364311, 'y0': 372.59368556340536, 'y1': 374.59368556340536}}]}
# point_index:  33935
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 35851, 'pointIndex': 35851, 'lon': 15.0083075, 'lat': 60.7277585, 'bbox': {'x0': 174.12308219425262, 'x1': 176.12308219425262, 'y0': 368.32705101777634, 'y1': 370.32705101777634}}]}
# point_index:  35851
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 71956, 'pointIndex': 71956, 'lon': 15.0693523, 'lat': 60.6897755, 'bbox': {'x0': 264.43828242014325, 'x1': 266.43828242014325, 'y0': 268.944829365753, 'y1': 270.944829365753}}]}
# point_index:  71956
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 36615, 'pointIndex': 36615, 'lon': 15.070842, 'lat': 60.6904203, 'bbox': {'x0': 287.3551959915767, 'x1': 289.3551959915767, 'y0': 248.68199365384996, 'y1': 250.68199365384996}}]}
# point_index:  36615
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 71145, 'pointIndex': 71145, 'lon': 15.0959118, 'lat': 60.6743003, 'bbox': {'x0': 473.01837634056335, 'x1': 475.01837634056335, 'y0': 381.1310756736332, 'y1': 383.1310756736332}}]}
# point_index:  71145
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 71763, 'pointIndex': 71763, 'lon': 15.0863541, 'lat': 60.680702, 'bbox': {'x0': 413.9867693469638, 'x1': 415.9867693469638, 'y0': 355.0364424336524, 'y1': 357.0364424336524}}]}
# point_index:  71763
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 36901, 'pointIndex': 36901, 'lon': 15.087076, 'lat': 60.6815385, 'bbox': {'x0': 425.0921730571323, 'x1': 427.0921730571323, 'y0': 328.75676994626485, 'y1': 330.75676994626485}}]}
# point_index:  36901
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 70402, 'pointIndex': 70402, 'lon': 15.0948371, 'lat': 60.6391136, 'bbox': {'x0': 373.3555919934833, 'x1': 375.3555919934833, 'y0': 324.7090997606989, 'y1': 326.7090997606989}}]}
# point_index:  70402
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 38753, 'pointIndex': 38753, 'lon': 15.0939966, 'lat': 60.6384343, 'bbox': {'x0': 360.42569613797326, 'x1': 362.42569613797326, 'y0': 346.0220992655981, 'y1': 348.0220992655981}}]}
# point_index:  38753
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 69980, 'pointIndex': 69980, 'lon': 15.0728361, 'lat': 60.613019, 'bbox': {'x0': 305.5561652830669, 'x1': 307.5561652830669, 'y0': 333.2660040950018, 'y1': 335.2660040950018}}]}
# point_index:  69980
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 69974, 'pointIndex': 69974, 'lon': 15.0728073, 'lat': 60.612636, 'bbox': {'x0': 305.1131182867383, 'x1': 307.1131182867383, 'y0': 345.27294386700976, 'y1': 347.27294386700976}}]}
# point_index:  69974
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 39355, 'pointIndex': 39355, 'lon': 15.0732168, 'lat': 60.6031503, 'bbox': {'x0': 460.2951128146005, 'x1': 462.2951128146005, 'y0': 249.88952995652244, 'y1': 251.88952995652244}}]}
# point_index:  39355
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 69781, 'pointIndex': 69781, 'lon': 15.074093, 'lat': 60.6030195, 'bbox': {'x0': 473.7742023426389, 'x1': 475.7742023426389, 'y0': 253.98883466379982, 'y1': 255.98883466379982}}]}
# point_index:  69781
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 40043, 'pointIndex': 40043, 'lon': 15.0912055, 'lat': 60.5937231, 'bbox': {'x0': 439.92032014642444, 'x1': 441.92032014642444, 'y0': 293.93023175966175, 'y1': 295.93023175966175}}]}
# point_index:  40043
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 68939, 'pointIndex': 68939, 'lon': 15.0912343, 'lat': 60.5945061, 'bbox': {'x0': 440.363367142753, 'x1': 442.363367142753, 'y0': 269.39763294477314, 'y1': 271.39763294477314}}]}
# point_index:  68939
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 40118, 'pointIndex': 40118, 'lon': 15.0991585, 'lat': 60.5919161, 'bbox': {'x0': 419.2659021415408, 'x1': 421.2659021415408, 'y0': 246.544061240885, 'y1': 248.544061240885}}]}
# point_index:  40118
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 68870, 'pointIndex': 68870, 'lon': 15.0991866, 'lat': 60.5922383, 'bbox': {'x0': 419.6981806346348, 'x1': 421.6981806346348, 'y0': 236.44967469506793, 'y1': 238.44967469506793}}]}
# point_index:  68870
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 40720, 'pointIndex': 40720, 'lon': 15.1336085, 'lat': 60.561713, 'bbox': {'x0': 369.4015137418868, 'x1': 371.4015137418868, 'y0': 236.21568556683405, 'y1': 238.21568556683405}}]}
# point_index:  40720
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 68247, 'pointIndex': 68247, 'lon': 15.1336413, 'lat': 60.5623095, 'bbox': {'x0': 369.90609504343973, 'x1': 371.90609504343973, 'y0': 217.54497822447428, 'y1': 219.54497822447428}}]}
# point_index:  68247
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 41774, 'pointIndex': 41774, 'lon': 15.2039166, 'lat': 60.5523068, 'bbox': {'x0': 361.2552799501116, 'x1': 363.2552799501116, 'y0': 267.758937602573, 'y1': 269.758937602573}}]}
# point_index:  41774
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 67038, 'pointIndex': 67038, 'lon': 15.2040983, 'lat': 60.5530628, 'bbox': {'x0': 364.05047575821953, 'x1': 366.05047575821953, 'y0': 244.10263445907168, 'y1': 246.10263445907168}}]}
# point_index:  67038
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 41973, 'pointIndex': 41973, 'lon': 15.2324291, 'lat': 60.55369, 'bbox': {'x0': 566.8794982247882, 'x1': 568.8794982247882, 'y0': 247.4762448553055, 'y1': 249.4762448553055}}]}
# point_index:  41973
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 66835, 'pointIndex': 66835, 'lon': 15.2323921, 'lat': 60.5542165, 'bbox': {'x0': 566.310305902693, 'x1': 568.310305902693, 'y0': 231.00067337543246, 'y1': 233.00067337543246}}]}
# point_index:  66835
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28277, 'pointIndex': 28277, 'lon': 14.9347348, 'lat': 60.8827275, 'bbox': {'x0': 473.03164795192464, 'x1': 475.03164795192464, 'y0': 411.15594198325323, 'y1': 413.15594198325323}}]}
# point_index:  28277
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28970, 'pointIndex': 28970, 'lon': 14.9707576, 'lat': 60.907739, 'bbox': {'x0': 396.80315799259006, 'x1': 398.80315799259006, 'y0': 170.59507328707076, 'y1': 172.59507328707076}}]}
# point_index:  28970
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28942, 'pointIndex': 28942, 'lon': 14.971073, 'lat': 60.9091965, 'bbox': {'x0': 399.9207514505538, 'x1': 401.9207514505538, 'y0': 140.9641061048659, 'y1': 142.9641061048659}}]}
# point_index:  28942
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28916, 'pointIndex': 28916, 'lon': 14.9680445, 'lat': 60.9099051, 'bbox': {'x0': 369.9853304374786, 'x1': 371.9853304374786, 'y0': 126.55778247288295, 'y1': 128.55778247288293}}]}
# point_index:  28916
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28859, 'pointIndex': 28859, 'lon': 14.9627115, 'lat': 60.908385, 'bbox': {'x0': 317.27091727521685, 'x1': 319.27091727521685, 'y0': 157.46206390668476, 'y1': 159.46206390668476}}]}
# point_index:  28859
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28840, 'pointIndex': 28840, 'lon': 14.9614801, 'lat': 60.9074958, 'bbox': {'x0': 305.099057464751, 'x1': 307.099057464751, 'y0': 175.53919610258134, 'y1': 177.53919610258134}}]}
# point_index:  28840
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 28821, 'pointIndex': 28821, 'lon': 14.9606995, 'lat': 60.9066126, 'bbox': {'x0': 297.38316192475577, 'x1': 299.38316192475577, 'y0': 193.49385124728792, 'y1': 195.49385124728792}}]}
# point_index:  28821
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 29240, 'pointIndex': 29240, 'lon': 15.0003116, 'lat': 60.9035066, 'bbox': {'x0': 403.8123354969517, 'x1': 405.8123354969517, 'y0': 285.3792527955676, 'y1': 287.3792527955676}}]}
# point_index:  29240
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 2093, 'pointIndex': 2093, 'lon': 14.6351576, 'lat': 60.982687, 'bbox': {'x0': 427.9001158155146, 'x1': 429.9001158155146, 'y0': 416.41546686802593, 'y1': 418.41546686802593}}]}
# point_index:  2093
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 2050, 'pointIndex': 2050, 'lon': 14.640551, 'lat': 60.9807681, 'bbox': {'x0': 451.3223639907345, 'x1': 453.3223639907345, 'y0': 433.5944435316419, 'y1': 435.5944435316419}}]}
# point_index:  2050
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 20467, 'pointIndex': 20467, 'lon': 14.6376436, 'lat': 60.9845246, 'bbox': {'x0': 438.6962201214026, 'x1': 440.6962201214026, 'y0': 399.96335723929934, 'y1': 401.96335723929934}}]}
# point_index:  20467
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 20426, 'pointIndex': 20426, 'lon': 14.6339963, 'lat': 60.9857803, 'bbox': {'x0': 422.8568672512259, 'x1': 424.8568672512259, 'y0': 388.72047549249635, 'y1': 390.72047549249635}}]}
# point_index:  20426
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 19576, 'pointIndex': 19576, 'lon': 14.5737313, 'lat': 61.008121, 'bbox': {'x0': 161.1403644344163, 'x1': 163.1403644344163, 'y0': 188.61921691203872, 'y1': 190.61921691203872}}]}
# point_index:  19576
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 19481, 'pointIndex': 19481, 'lon': 14.5696363, 'lat': 61.0083526, 'bbox': {'x0': 143.35675738160572, 'x1': 145.35675738160572, 'y0': 186.54408396274323, 'y1': 188.54408396274323}}]}
# point_index:  19481
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 3005, 'pointIndex': 3005, 'lon': 14.5698843, 'lat': 61.009089, 'bbox': {'x0': 274.78307704130805, 'x1': 276.78307704130805, 'y0': 277.67714717747674, 'y1': 279.67714717747674}}]}
# point_index:  3005
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 3159, 'pointIndex': 3159, 'lon': 14.563736, 'lat': 61.0091675, 'bbox': {'x0': 331.009773811083, 'x1': 333.009773811083, 'y0': 307.0761849806422, 'y1': 309.0761849806422}}]}
# point_index:  3159
# segments.shape[0] =  14400
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 19452, 'pointIndex': 19452, 'lon': 14.5684293, 'lat': 61.008463, 'bbox': {'x0': 377.40102738236624, 'x1': 379.40102738236624, 'y0': 321.44391393074915, 'y1': 323.44391393074915}}]}
# point_index:  19452
# segments.shape[0] =  14400
# selected segment =segments[-1]
# Clickdata: {'points': [{'curveNumber': 0, 'pointNumber': 3582, 'pointIndex': 3582, 'lon': 14.5586758, 'lat': 61.0095408, 'bbox': {'x0': 280.9918714141089, 'x1': 282.9918714141089, 'y0': 299.46289291533213, 'y1': 301.46289291533213}}]}
# point_index:  3582
# segments.shape[0] =  14400
